# %%
# !pip install py_midicsv

# %%
# !pip install music21
# Out:
# ...
#      |████████████████████████████████| 18.5 MB 12.2 MB/s eta 0:00:01
# ...
#   Created wheel for music21: filename=music21-5.7.2-py3-none-any.whl size=22024602 sha256=536a2412fd9e7d114aef5ca0645047cefe212470bcfcaa16bb1ceafc0cfe6a29
#   Stored in directory: /home/dmh/.cache/pip/wheels/bc/cb/ae/fd264ebf1e9cf01c15576ee4c128f1bfd907a120c0a7a5b542
# Successfully built music21
# ...

# %%
import music21
import csv
mf=music21.midi.MidiFile()
mf.open("../data/maestro-v2.0.0/2018/MIDI-Unprocessed_Chamber1_MID--AUDIO_07_R3_2018_wav--2.midi")
mf.read()
mf.close()
midi_stream=music21.midi.translate.midiFileToStream(mf)
midi_stream.show('text')

# Load the MIDI file and parse it into CSV format
# csv_string = py_midicsv.midi_to_csv("../data/maestro-v2.0.0/2018/MIDI-Unprocessed_Chamber1_MID--AUDIO_07_R3_2018_wav--2.midi")
# csv_string# Load the MIDI file and parse it into CSV format
# with open('../outputs/output.txt','w') as result_file:
#     wr = csv.writer(result_file, dialect='excel')
#     wr.writerows(csv_string)
# Out:
# {0.0} <music21.stream.Part 0x7fb4c43fd5d0>
#     {0.0} <music21.instrument.Piano 'Piano'>
#     {0.0} <music21.tempo.MetronomeMark animato Quarter=120.0>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Voice 0x7fb49aaa56d0>
#         {0.0} <music21.note.Rest rest>
#         {2.0} <music21.chord.Chord D5 D2>
#         {2.5} <music21.chord.Chord C#5 C#2 B-1>
#         {2.5} <music21.note.Note B>
#         {3.0} <music21.chord.Chord G5 G2>
#         {3.3333} <music21.chord.Chord F#5 F#2>
#         {3.75} <music21.chord.Chord E5 E2>
#         {4.0} <music21.chord.Chord D5 D2>
#         {4.5} <music21.chord.Chord B2 B5 C6>
#         {4.75} <music21.chord.Chord A2 A5>
#         {5.0} <music21.chord.Chord G5 G2>
#         {5.3333} <music21.chord.Chord F#5 F#2>
#         {5.75} <music21.chord.Chord D3 D6>
#         {6.0} <music21.chord.Chord C#3 C#6>
#         {6.3333} <music21.chord.Chord B2 B5>
#         {6.75} <music21.chord.Chord A5 A2>
# ...
